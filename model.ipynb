png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_24_mixed_aug2_row440_col6380.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_10_mixed_aug2_row3300_col440.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug0_row1320_col9240.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_10_mixed_aug1_row7700_col6600.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug1_row8140_col9680.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug3_row7700_col8140.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_10_mixed_aug0_row6600_col10560.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug2_row8800_col1540.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug3_row6820_col9680.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug0_row4840_col6820.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_1_mixed_aug2_row3300_col3080.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug0_row4180_col10120.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_1_mixed_aug4_row7260_col8580.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug0_row3080_col3740.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug0_row5280_col1320.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_land_aug2_row9020_col5720.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug2_row8140_col3520.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug1_row5280_col3080.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug0_row3960_col4840.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug0_row8360_col10560.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_24_mixed_aug4_row8580_col9680.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug4_row5720_col7480.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_10_mixed_aug0_row2420_col8140.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug0_row7260_col1980.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug3_row220_col6380.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug3_row7920_col3300.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug1_row7480_col880.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug1_row9680_col1980.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_10_mixed_aug3_row0_col7040.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug4_row2640_col1100.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug3_row5500_col1760.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_land_aug2_row6380_col5060.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_mixed_aug0_row880_col220.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug3_row10340_col6160.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug0_row8580_col9240.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug2_row3740_col10560.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_mixed_aug0_row7920_col9240.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_1_mixed_aug2_row9460_col9900.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_10_mixed_aug4_row4840_col6600.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug4_row7040_col1760.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug4_row8140_col7920.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug4_row1540_col3960.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug1_row9240_col8800.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug0_row2420_col440.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_24_mixed_aug2_row4620_col7040.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_1_mixed_aug4_row440_col0.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug4_row5280_col3740.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_mixed_aug0_row1320_col10340.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug0_row2420_col2420.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug4_row8580_col4840.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug1_row9900_col7700.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_land_aug4_row9020_col3960.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug4_row440_col8580.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_land_aug4_row4180_col5060.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_14_mixed_aug2_row5500_col7480.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_mixed_aug1_row5720_col2860.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_1_mixed_aug1_row5720_col4400.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug3_row4620_col660.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_land_aug2_row3740_col3740.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_mixed_aug3_row2420_col440.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_10_mixed_aug2_row3960_col5500.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug4_row6160_col880.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug1_row8140_col4840.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug0_row3300_col3300.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_1_mixed_aug3_row7260_col7040.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug1_row2860_col0.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_1_mixed_aug4_row7920_col9240.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug0_row9680_col440.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_26_mixed_aug0_row1980_col7260.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug3_row3300_col7920.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug2_row10340_col440.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_mixed_aug3_row220_col7700.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_20_mixed_aug4_row4400_col9240.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_24_mixed_aug1_row7260_col7480.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_15_land_aug2_row10120_col8140.png
# /kaggle/input/balanced-ds/FinalDataset/masks/Image_21_water_aug1_row5500_col5280.png

# %%
# --- Imports ---
import tensorflow as tf
import numpy as np
import random
import os
import glob
from tqdm.notebook import tqdm
import rasterio
import math
import warnings
from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')

# --- 1. Setup & Configuration ---
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# --- Dataset Path ---
BASE_DATA_PATH = '/kaggle/input/balanced-ds/FinalDataset' 

IMAGES_DIR = os.path.join(BASE_DATA_PATH, 'images')
MASKS_DIR = os.path.join(BASE_DATA_PATH, 'masks')

# --- Image Dimensions ---
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 12

# --- Training Configuration ---
BATCH_SIZE = 8
BUFFER_SIZE = 1000
EPOCHS = 50
NUM_ADAPT_BATCHES = 500

# --- Model Checkpoint Path ---
MODEL_CHECKPOINT_PATH = '/kaggle/working/coastline_unet_model_s2_adapt.keras'
TENSORBOARD_LOG_DIR = '/kaggle/working/logs_coastline_s2_adapt'

# --- 2. Data Loading & Splitting ---
def get_all_file_paths(images_dir, masks_dir):
    image_files = sorted(glob.glob(os.path.join(images_dir, '*.jp2')))
    mask_files = sorted(glob.glob(os.path.join(masks_dir, '*.png')))
    
    if len(image_files) != len(mask_files):
        raise ValueError("Mismatch between number of images and masks!")
    return image_files, mask_files

print("Loading file paths...")
all_image_files, all_mask_files = get_all_file_paths(IMAGES_DIR, MASKS_DIR)

# --- Train/Validation Split (80:20) ---
print("Splitting dataset into train and validation (80:20)...")
train_img_files, val_img_files, train_mask_files, val_mask_files = train_test_split(
    all_image_files, all_mask_files, test_size=0.2, random_state=SEED
)

print(f"Training images: {len(train_img_files)}")
print(f"Validation images: {len(val_img_files)}")

# --- 3. Data Preprocessing Functions ---
@tf.function
def parse_image_mask(img_path, mask_path):
    def read_jp2(path):
        path = path.numpy().decode('utf-8')
        with rasterio.open(path) as img_ds:
            img = img_ds.read().astype(np.float32)  # (channels, H, W)
            img = np.transpose(img, (1, 2, 0))  # (H, W, channels)
            return img

    img = tf.py_function(read_jp2, [img_path], tf.float32)
    img.set_shape([IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS])

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    mask = tf.cast(mask, tf.float32)
    mask = tf.cast(mask > 127.0, tf.float32)

    return img, mask

def create_tf_dataset(image_files, mask_files, batch_size, shuffle=False, buffer_size=1000):
    dataset = tf.data.Dataset.from_tensor_slices((image_files, mask_files))
    if shuffle:
        dataset = dataset.shuffle(buffer_size)
    dataset = dataset.map(parse_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# --- 4. Create Datasets ---
print("Creating datasets...")
train_dataset = create_tf_dataset(train_img_files, train_mask_files, BATCH_SIZE, shuffle=True, buffer_size=BUFFER_SIZE)
val_dataset = create_tf_dataset(val_img_files, val_mask_files, BATCH_SIZE)

num_train_samples = len(train_img_files)
num_val_samples = len(val_img_files)
steps_per_epoch = math.ceil(num_train_samples / BATCH_SIZE)
validation_steps = math.ceil(num_val_samples / BATCH_SIZE)

# --- 5. Normalize the Data ---
print("Adapting normalization layer...")
normalization_layer = tf.keras.layers.Normalization(axis=-1)
adapt_dataset = train_dataset.map(lambda img, mask: img).take(NUM_ADAPT_BATCHES)
normalization_layer.adapt(adapt_dataset)

# --- 6. U-Net Model ---
def conv_block(inputs, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, activation="relu", kernel_initializer="he_normal", padding="same")(inputs)
    x = tf.keras.layers.Dropout(0.1)(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, activation="relu", kernel_initializer="he_normal", padding="same")(x)
    return x

def upsample_block(inputs, skip, num_filters):
    up = tf.keras.layers.Conv2DTranspose(num_filters, 2, strides=2, padding="same")(inputs)
    concat = tf.keras.layers.concatenate([up, skip])
    x = conv_block(concat, num_filters)
    return x

def build_unet(input_shape, norm_layer):
    inputs = tf.keras.layers.Input(input_shape)
    s = norm_layer(inputs)

    # Encoder
    c1 = conv_block(s, 16); p1 = tf.keras.layers.MaxPooling2D(2)(c1)
    c2 = conv_block(p1, 32); p2 = tf.keras.layers.MaxPooling2D(2)(c2)
    c3 = conv_block(p2, 64); p3 = tf.keras.layers.MaxPooling2D(2)(c3)
    c4 = conv_block(p3, 128); p4 = tf.keras.layers.MaxPooling2D(2)(c4)

    # Bridge
    c5 = conv_block(p4, 256)

    # Decoder
    c6 = upsample_block(c5, c4, 128)
    c7 = upsample_block(c6, c3, 64)
    c8 = upsample_block(c7, c2, 32)
    c9 = upsample_block(c8, c1, 16)

    outputs = tf.keras.layers.Conv2D(1, 1, activation='sigmoid')(c9)

    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# --- Build and Compile Model ---
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
model = build_unet(input_shape, normalization_layer)

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_pred_pos = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred_pos, axis=[1,2,3])
    union = tf.reduce_sum(y_true, axis=[1,2,3]) + tf.reduce_sum(y_pred_pos, axis=[1,2,3]) - intersection
    return tf.reduce_mean((intersection + smooth) / (union + smooth))

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy", iou_metric]
)
model.summary()

# --- 7. Callbacks ---
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=15, monitor='val_iou_metric', mode='max', restore_best_weights=True, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(MODEL_CHECKPOINT_PATH, monitor='val_iou_metric', save_best_only=True, verbose=1, mode='max'),
    tf.keras.callbacks.TensorBoard(log_dir=TENSORBOARD_LOG_DIR),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7, verbose=1)
]

# --- 8. Train the Model ---
print("\nStarting training...")
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_dataset,
    validation_steps=validation_steps,
    callbacks=callbacks
)
print(f"\nTraining completed. Best model saved at: {MODEL_CHECKPOINT_PATH}")
# Out:
# Loading file paths...
# Splitting dataset into train and validation (80:20)...
# Training images: 16800
# Validation images: 4200
# Creating datasets...
# I0000 00:00:1745944559.051171      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1745944559.051840      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Adapting normalization layer...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 12)   │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 256, 256, 12)   │             25 │ input_layer[0][0]      │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 16)   │          1,744 │ normalization[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256, 256, 16)   │              0 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 16)   │          2,320 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 16)   │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 32)   │          4,640 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128, 128, 32)   │              0 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 32)   │          9,248 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 32)     │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 64)     │         18,496 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 64, 64, 64)     │              0 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 64)     │         36,928 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 64)     │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 128)    │         73,856 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 32, 32, 128)    │              0 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 128)    │        147,584 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 128)    │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 16, 16, 256)    │        295,168 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 16, 16, 256)    │              0 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 256)    │        590,080 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 128)    │        131,200 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 256)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 128)    │        295,040 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 32, 32, 128)    │              0 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 128)    │        147,584 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 64)     │         32,832 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 128)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 64, 64, 64)     │              0 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 32)   │          8,224 │ conv2d_13[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 64)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 32)   │         18,464 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128, 128, 32)   │              0 │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 16)   │          2,064 │ conv2d_15[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 256, 256, 32)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 256, 256, 16)   │          4,624 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 256, 256, 16)   │              0 │ conv2d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 256, 256, 16)   │          2,320 │ dropout_8[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 256, 256, 1)    │             17 │ conv2d_17[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,942,426 (7.41 MB)
#  Trainable params: 1,942,401 (7.41 MB)
#  Non-trainable params: 25 (104.00 B)
# Starting training...
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745944716.534467     103 service.cc:148] XLA service 0x7fb848005210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745944716.535336     103 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1745944716.535356     103 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1745944718.001734     103 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745944734.263078     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9144 - iou_metric: 0.5451 - loss: 0.2424
# Epoch 1: val_iou_metric improved from -inf to 0.82354, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 786s 361ms/step - accuracy: 0.9144 - iou_metric: 0.5451 - loss: 0.2424 - val_accuracy: 0.9291 - val_iou_metric: 0.8235 - val_loss: 0.1711 - learning_rate: 1.0000e-04
# Epoch 2/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9318 - iou_metric: 0.8002 - loss: 0.1713
# Epoch 3: val_iou_metric improved from 0.82354 to 0.82939, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 667s 318ms/step - accuracy: 0.9318 - iou_metric: 0.8002 - loss: 0.1713 - val_accuracy: 0.9312 - val_iou_metric: 0.8294 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 4/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9356 - iou_metric: 0.8222 - loss: 0.1616
# Epoch 5: val_iou_metric improved from 0.82939 to 0.84382, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 666s 317ms/step - accuracy: 0.9356 - iou_metric: 0.8222 - loss: 0.1616 - val_accuracy: 0.9407 - val_iou_metric: 0.8438 - val_loss: 0.1489 - learning_rate: 1.0000e-04
# Epoch 6/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 12us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9396 - iou_metric: 0.8298 - loss: 0.1518
# Epoch 7: val_iou_metric improved from 0.84382 to 0.84871, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 667s 318ms/step - accuracy: 0.9396 - iou_metric: 0.8298 - loss: 0.1518 - val_accuracy: 0.9426 - val_iou_metric: 0.8487 - val_loss: 0.1502 - learning_rate: 1.0000e-04
# Epoch 8/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 9/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9405 - iou_metric: 0.8299 - loss: 0.1491
# Epoch 9: val_iou_metric improved from 0.84871 to 0.85580, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 671s 320ms/step - accuracy: 0.9405 - iou_metric: 0.8299 - loss: 0.1491 - val_accuracy: 0.9418 - val_iou_metric: 0.8558 - val_loss: 0.1521 - learning_rate: 1.0000e-04
# Epoch 10/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 11/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9414 - iou_metric: 0.8332 - loss: 0.1453
# Epoch 11: val_iou_metric did not improve from 0.85580
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 668s 318ms/step - accuracy: 0.9414 - iou_metric: 0.8332 - loss: 0.1453 - val_accuracy: 0.9421 - val_iou_metric: 0.8546 - val_loss: 0.1467 - learning_rate: 1.0000e-04
# Epoch 12/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 12us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 13/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9433 - iou_metric: 0.8376 - loss: 0.1399
# Epoch 13: val_iou_metric improved from 0.85580 to 0.85891, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 672s 320ms/step - accuracy: 0.9433 - iou_metric: 0.8376 - loss: 0.1399 - val_accuracy: 0.9437 - val_iou_metric: 0.8589 - val_loss: 0.1478 - learning_rate: 1.0000e-04
# Epoch 14/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 12us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 15/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9435 - iou_metric: 0.8411 - loss: 0.1389
# Epoch 15: val_iou_metric improved from 0.85891 to 0.86138, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 670s 319ms/step - accuracy: 0.9435 - iou_metric: 0.8411 - loss: 0.1389 - val_accuracy: 0.9442 - val_iou_metric: 0.8614 - val_loss: 0.1425 - learning_rate: 1.0000e-04
# Epoch 16/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 16us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 17/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9433 - iou_metric: 0.8393 - loss: 0.1390
# Epoch 17: val_iou_metric improved from 0.86138 to 0.86414, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 669s 319ms/step - accuracy: 0.9433 - iou_metric: 0.8393 - loss: 0.1390 - val_accuracy: 0.9469 - val_iou_metric: 0.8641 - val_loss: 0.1362 - learning_rate: 1.0000e-04
# Epoch 18/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 19/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9461 - iou_metric: 0.8468 - loss: 0.1324
# Epoch 19: val_iou_metric did not improve from 0.86414
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 670s 319ms/step - accuracy: 0.9461 - iou_metric: 0.8468 - loss: 0.1324 - val_accuracy: 0.9412 - val_iou_metric: 0.8573 - val_loss: 0.1508 - learning_rate: 1.0000e-04
# Epoch 20/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 21/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9456 - iou_metric: 0.8417 - loss: 0.1332
# Epoch 21: val_iou_metric did not improve from 0.86414
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 666s 317ms/step - accuracy: 0.9456 - iou_metric: 0.8417 - loss: 0.1332 - val_accuracy: 0.9475 - val_iou_metric: 0.8598 - val_loss: 0.1307 - learning_rate: 1.0000e-04
# Epoch 22/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 23/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9457 - iou_metric: 0.8434 - loss: 0.1315
# Epoch 23: val_iou_metric did not improve from 0.86414
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 665s 317ms/step - accuracy: 0.9457 - iou_metric: 0.8434 - loss: 0.1315 - val_accuracy: 0.9438 - val_iou_metric: 0.8594 - val_loss: 0.1373 - learning_rate: 1.0000e-04
# Epoch 24/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 12us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 25/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9463 - iou_metric: 0.8481 - loss: 0.1299
# Epoch 25: val_iou_metric improved from 0.86414 to 0.86632, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 668s 318ms/step - accuracy: 0.9463 - iou_metric: 0.8482 - loss: 0.1299 - val_accuracy: 0.9483 - val_iou_metric: 0.8663 - val_loss: 0.1312 - learning_rate: 1.0000e-04
# Epoch 26/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 27/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9460 - iou_metric: 0.8478 - loss: 0.1290
# Epoch 27: val_iou_metric did not improve from 0.86632
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 676s 322ms/step - accuracy: 0.9460 - iou_metric: 0.8478 - loss: 0.1290 - val_accuracy: 0.9446 - val_iou_metric: 0.8645 - val_loss: 0.1426 - learning_rate: 1.0000e-04
# Epoch 28/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 29/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9469 - iou_metric: 0.8488 - loss: 0.1282
# Epoch 29: val_iou_metric improved from 0.86632 to 0.86968, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 666s 317ms/step - accuracy: 0.9469 - iou_metric: 0.8488 - loss: 0.1282 - val_accuracy: 0.9483 - val_iou_metric: 0.8697 - val_loss: 0.1310 - learning_rate: 1.0000e-04
# Epoch 30/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 31/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9479 - iou_metric: 0.8508 - loss: 0.1258
# Epoch 31: val_iou_metric improved from 0.86968 to 0.87223, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 675s 321ms/step - accuracy: 0.9479 - iou_metric: 0.8508 - loss: 0.1258 - val_accuracy: 0.9486 - val_iou_metric: 0.8722 - val_loss: 0.1304 - learning_rate: 1.0000e-04
# Epoch 32/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 33/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9472 - iou_metric: 0.8525 - loss: 0.1254
# Epoch 33: val_iou_metric improved from 0.87223 to 0.87325, saving model to /kaggle/working/coastline_unet_model_s2_adapt.keras
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 671s 319ms/step - accuracy: 0.9472 - iou_metric: 0.8525 - loss: 0.1254 - val_accuracy: 0.9501 - val_iou_metric: 0.8733 - val_loss: 0.1239 - learning_rate: 1.0000e-04
# Epoch 34/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 35/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9492 - iou_metric: 0.8571 - loss: 0.1216
# Epoch 35: val_iou_metric did not improve from 0.87325
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 666s 317ms/step - accuracy: 0.9492 - iou_metric: 0.8571 - loss: 0.1216 - val_accuracy: 0.9461 - val_iou_metric: 0.8685 - val_loss: 0.1443 - learning_rate: 1.0000e-04
# Epoch 36/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 37/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9492 - iou_metric: 0.8575 - loss: 0.1210
# Epoch 37: val_iou_metric did not improve from 0.87325
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 669s 318ms/step - accuracy: 0.9492 - iou_metric: 0.8575 - loss: 0.1210 - val_accuracy: 0.9490 - val_iou_metric: 0.8719 - val_loss: 0.1270 - learning_rate: 1.0000e-04
# Epoch 38/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 39/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9502 - iou_metric: 0.8579 - loss: 0.1181
# Epoch 39: val_iou_metric did not improve from 0.87325
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 668s 318ms/step - accuracy: 0.9502 - iou_metric: 0.8579 - loss: 0.1181 - val_accuracy: 0.9503 - val_iou_metric: 0.8731 - val_loss: 0.1242 - learning_rate: 1.0000e-04
# Epoch 40/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 12us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 41/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9507 - iou_metric: 0.8602 - loss: 0.1173
# Epoch 41: val_iou_metric did not improve from 0.87325
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 672s 320ms/step - accuracy: 0.9507 - iou_metric: 0.8602 - loss: 0.1173 - val_accuracy: 0.9482 - val_iou_metric: 0.8690 - val_loss: 0.1334 - learning_rate: 1.0000e-04
# Epoch 42/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 12us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 43/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9506 - iou_metric: 0.8598 - loss: 0.1167
# Epoch 43: val_iou_metric did not improve from 0.87325
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 669s 318ms/step - accuracy: 0.9506 - iou_metric: 0.8598 - loss: 0.1167 - val_accuracy: 0.9505 - val_iou_metric: 0.8723 - val_loss: 0.1260 - learning_rate: 1.0000e-04
# Epoch 44/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 45/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9537 - iou_metric: 0.8669 - loss: 0.1065
# Epoch 45: val_iou_metric did not improve from 0.87325
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 670s 319ms/step - accuracy: 0.9537 - iou_metric: 0.8669 - loss: 0.1065 - val_accuracy: 0.9498 - val_iou_metric: 0.8683 - val_loss: 0.1276 - learning_rate: 2.0000e-05
# Epoch 46/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 47/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9548 - iou_metric: 0.8687 - loss: 0.1030
# Epoch 47: val_iou_metric did not improve from 0.87325
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 667s 318ms/step - accuracy: 0.9548 - iou_metric: 0.8687 - loss: 0.1030 - val_accuracy: 0.9503 - val_iou_metric: 0.8687 - val_loss: 0.1276 - learning_rate: 2.0000e-05
# Epoch 48/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 49/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9567 - iou_metric: 0.8684 - loss: 0.0995
# Epoch 49: val_iou_metric did not improve from 0.87325
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 670s 319ms/step - accuracy: 0.9567 - iou_metric: 0.8684 - loss: 0.0995 - val_accuracy: 0.9512 - val_iou_metric: 0.8669 - val_loss: 0.1249 - learning_rate: 2.0000e-05
# Epoch 50/50
# 2100/2100 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step - accuracy: 0.0000e+00 - iou_metric: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.0000e-05
# Restoring model weights from the end of the best epoch: 33.
#
# Training completed. Best model saved at: /kaggle/working/coastline_unet_model_s2_adapt.keras
